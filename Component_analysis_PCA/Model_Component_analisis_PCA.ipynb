# %%
#Code with the topic : Component analysis PCA

#Objective:

## Apply Principal Component Analysis (PCA) to reduce the
# dimensionality of a dataset while preserving most of the
# original information.


#Technologies:

#Pandas
#Python
#Scikit learn
#Visual Studio Code
#Jupyter notebook

#Method used:

#PCA

# %%
#We import libraries

import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#Load the dataset

data = pd.read_csv("Component_analysis_PCA.csv")

# %%
data.describe()
# Out:
#              Age         Income      Spending      Score
# count   9.000000       9.000000      9.000000   9.000000
# mean   37.666667   85777.777778   3366.666667  86.333333
# std     8.930286   81642.173198   4384.917331   9.733961
# min    25.000000   35000.000000   1200.000000  70.000000
# 25%    30.000000   50000.000000   1800.000000  80.000000
# 50%    38.000000   62000.000000   2000.000000  88.000000
# 75%    45.000000   75000.000000   2400.000000  95.000000
# max    50.000000  300000.000000  15000.000000  98.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       9 non-null      int64
#  1   Income    9 non-null      int64
#  2   Spending  9 non-null      int64
#  3   Score     9 non-null      int64
#  4   Class     9 non-null      object
# dtypes: int64(4), object(1)
# memory usage: 492.0+ bytes

# %%
data.head()
# Out:
#    Age  Income  Spending  Score Class
# 0   25  300000      1200     70     A
# 1   30   45000     15000     80     A
# 2   35   50000      1800     85     A
# 3   40   62000      2000     90     B
# 4   45   70000      2200     95     C

# %%
#Separate features (X) and target variables (Y)

X = data.drop("Class", axis=1)
y = data["Class"]

# %%
#Standardize the features

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Apply PCA to reduce the datato two principal components

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
#Create a DataFrame with the transformed data

results = pd.DataFrame(
    X_pca,
    columns=["Principal Component 1", "Principal Component 2"]

)

results["Class"] = y

# %%
#Display the explained Variance

print("Explained variance ratio of each component:")
print(pca.explained_variance_ratio_)

print("\nTotal explained variance:")
print(sum(pca.explained_variance_ratio_))
# Out:
# Explained variance ratio of each component:
# [0.57205679 0.30094226]
#
# Total explained variance:
# 0.872999047323987

# %%
#Plot the results

plt.figure(figsize=(8,6))

for label in results["Class"].unique():
    subset = results[results["Class"] == label]
    plt.scatter(
        subset["Principal Component 1"],
        subset["Principal Component 2"],
        label=label
    )

# %%
plt.title("Principal Component Analysis (PCA)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Selene\AppData\Local\Temp\ipykernel_15352\3738593260.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
