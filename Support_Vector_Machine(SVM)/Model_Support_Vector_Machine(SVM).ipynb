# %% [markdown]
# #Code with the topic: Support Vector Machine (SVM)
#
# #Objective:
#
# #This is a code example showing how the SVM algorithm works as a classifier.
#
# #Techologies:
#
# #Pandas
# #Python
# #Visual Studio Code
# #Scikit-learn
# #Jupyter notebook
#
# #Method used:
#
# #SVM

# %%
#we import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#We load the dataset

data = pd.read_csv("Support_Vector_Machine(SVM).csv")

# %%
data.head()
# Out:
#    feature  feature2  feature3  target
# 0      5.1       3.5       1.4       0
# 1      4.9       3.0       1.4       0
# 2      5.0       3.6       1.5       0
# 3      5.4       3.9       1.7       0
# 4      4.6       3.4       1.4       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   feature   10 non-null     float64
#  1   feature2  10 non-null     float64
#  2   feature3  10 non-null     float64
#  3   target    10 non-null     int64
# dtypes: float64(3), int64(1)
# memory usage: 452.0 bytes

# %%
data.describe()
# Out:
#          feature   feature2   feature3     target
# count  10.000000  10.000000  10.000000  10.000000
# mean    5.730000   3.200000   3.010000   0.500000
# std     0.887005   0.447214   1.630576   0.527046
# min     4.600000   2.300000   1.400000   0.000000
# 25%     5.025000   3.025000   1.425000   0.000000
# 50%     5.450000   3.200000   2.850000   0.500000
# 75%     6.475000   3.475000   4.575000   1.000000
# max     7.000000   3.900000   4.900000   1.000000

# %%
data.columns
# Out:
# Index(['feature', 'feature2', 'feature3', 'target'], dtype='object')

# %%
#Separate features and target variable

X = data.drop("target", axis=1)
Y = data["target"]

# %%
#Split data (train/test)

x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
#Data Scaling (Important for SVM)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#Create and train SVM model

model = SVC(kernel="rbf", C=1.0, gamma="scale")
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
#Predictions

y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="target", data=data, palette="viridis")

plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()
# Out:
# C:\Users\Selene\AppData\Local\Temp\ipykernel_16268\3925802082.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="target", data=data, palette="viridis")

# %%
#Model evaluation

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#
# Matriz de confusión:
#  [[1 0]
#  [0 1]]
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
