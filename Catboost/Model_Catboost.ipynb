# %% [markdown]
# #Code with the topic: Catboost
#
# #Objective:
#
# #The purpose of this code is to explain the steps involved in structuring the CatBoost algorithm.
#
# Technologies:
#
# #Pandas
# #scikit learn
# #Python
# #Python
# #Visual Studio Code
#
# #Method used:
#
# #CatBoost Classification

# %%
#Import libraries

import pandas as pd
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 4
#       1 #Import libraries
#       3 import pandas as pd
# ----> 4 from catboost import CatBoostClassifier
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay)
#
# ModuleNotFoundError: No module named 'catboost'
# Exception ignored in: 'zmq.backend.cython._zmq.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/_zmq.py", line 179, in zmq.backend.cython._zmq._check_rc
#     PyErr_CheckSignals()
# KeyboardInterrupt:

# %%
#Load CSV dataset

# %%
data = pd.read_csv("Catboost.csv")

# %%
data.head()
# Out:
#    age  salary  experience  purchase
# 0   25   30000           2         0
# 1   30   45000           5         1
# 2   22   28000           1         0
# 3   40   70000          10         1
# 4   28   38000          15         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         12 non-null     int64
#  1   salary      12 non-null     int64
#  2   experience  12 non-null     int64
#  3   purchase    12 non-null     int64
# dtypes: int64(4)
# memory usage: 516.0 bytes

# %%
data.describe()
# Out:
#              age        salary  experience   purchase
# count  12.000000     12.000000   12.000000  12.000000
# mean   33.083333  53916.666667    7.750000   0.750000
# std     7.178989  18836.417018    4.807664   0.452267
# min    22.000000  28000.000000    1.000000   0.000000
# 25%    27.500000  37250.000000    4.250000   0.750000
# 50%    32.500000  52500.000000    8.000000   1.000000
# 75%    38.500000  70500.000000   10.500000   1.000000
# max    45.000000  80000.000000   15.000000   1.000000

# %%
#Column names

data.columns
# Out:
# Index(['age', 'salary', 'experience', 'purchase'], dtype='object')

# %%
# Check missing values
print("\nMissing values:")
print(data.isnull().sum())

# %%
# Check duplicated rows
print("\nDuplicated rows:", data.duplicated().sum())

# %%
# Features and target variable

X = data.drop("purchase", axis = 1)
Y = data["purchase"]

# %%
#Split Dataset

x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.2,stratify=Y,
 random_state=42)

# %%
#Create Catboost model

model = CatBoostClassifier(
    iterations=300,
    learning_rate=0.05,
    depth=6,
    loss_function="Logloss",
    eval_metric="Accuracy",
    random_state=42,
    verbose=0

)

# %%
#Train Model

model.fit(x_train,y_train, eval_set=(x_test, y_test), use_best_model=True)

# %%
#Prediction

predictions = model.predict(x_test)

# %%
#Model Evaluation

accuracy = accuracy_score(y_test, predictions)

print("="* 50)

print(f"Accuracy : {accuracy:.4f}")
print("Classification Report")
print(classification_report(y_test, predictions))

# %%
#Confusion Matrix

# %%
cm = confusion_matrix(y_test, predictions)
print(cm)
