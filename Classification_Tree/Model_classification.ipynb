# %% [markdown]
# #Code with the topic: Classification Tree using scikit learn
#
# #Description:
#
# # This project demonstrates how a Decision Tree Classifier works
# # using a simple dataset.
#
#
# #Technologies:
#
# #Pandas
# #Scikit learn
# #Python
# #Jupyter notebook
#
# #Method used
#
# #tree Classification
#
# #How to use the code:
#
# #We will use this code as an example of the use of a classification #tree, which has as its theme the way in which the game "Who am I?" #is played, since for each branch another is discovered until the #final result is reached.

# %%
#We import the libraries

import pandas as pd
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import (accuracy_score,classification_report, confusion_matrix)

from sklearn import tree

# %%
#We use pandas to load 

data = pd.read_csv("Classification_tree.csv")

# %%
#We see our data in a table

data.head()
# Out:
#    age  salary  experience purchase
# 0   25    3000           1       No
# 1   30    4500           3       Si
# 2   35    5000           5       Si
# 3   22    2000           0       No
# 4   40    6500          10       Si

# %%
data.describe()
# Out:
#              age       salary  experience
# count  20.000000    20.000000   20.000000
# mean   31.400000  4320.000000    4.500000
# std     7.162769  1710.524696    4.762794
# min    21.000000  1800.000000    0.000000
# 25%    25.750000  2950.000000    1.000000
# 50%    30.500000  4400.000000    3.000000
# 75%    36.500000  5300.000000    6.250000
# max    45.000000  7200.000000   15.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         20 non-null     int64
#  1   salary      20 non-null     int64
#  2   experience  20 non-null     int64
#  3   purchase    20 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 772.0+ bytes

# %%
print(data)
# Out:
#     age  salary  experience purchase
# 0    25    3000           1       No
# 1    30    4500           3       Si
# 2    35    5000           5       Si
# 3    22    2000           0       No
# 4    40    6500          10       Si
# 5    28    3500           2       No
# 6    32    4800           4       Si
# 7    26    2800           1       No
# 8    45    7000          15       Si
# 9    23    2200           0       No
# 10   36    5200           6       Si
# 11   29    3900           2       No
# 12   41    6800          12       Si
# 13   27    3100           1       No
# 14   38    5600           7       Si
# 15   24    2500           0       No
# 16   33    4700           4       Si
# 17   31    4300           3       Si
# 18   21    1800           0       No
# 19   42    7200          14       Si

# %%
#We use columns so we don't make mistakes when writing the variables
data.columns
# Out:
# Index(['age', 'salary', 'experience', 'purchase'], dtype='object')

# %%
#We define X and Y

X = data[["age","salary","experience"]]
Y = data["purchase"]

# %%
#We separate training and testing

x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3, random_state=42)

# %%
#We create the model:

model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=4,
    random_state=42
)

# %%
#We trained the model

model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
#We make predictions

y_pred = model.predict(x_test)

# %%
#We evaluate the model

accuracy = accuracy_score(y_test,y_pred)

# %%
print("\n================================")
print("ACCURACY MODEL")
print("================================")
print(accuracy)

print("\n================================")
print("CLASSIFICATION REPORT")
print("================================")
print(classification_report(y_test, y_pred))

print("\n================================")
print("Confusion Matrix")
print("================================")
print(confusion_matrix(y_test, y_pred))
# Out:
# ...
# ACCURACY MODEL
# ...
# 0.8333333333333334
#
# ...
# CLASSIFICATION REPORT
# ...
#               precision    recall  f1-score   support
#
#           No       0.75      1.00      0.86         3
#           Si       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.88      0.83      0.83         6
# weighted avg       0.88      0.83      0.83         6
#
#
# ...
# Confusion Matrix
# ...
# [[3 0]
#  [1 2]]

# %%
#We visualize the model :

plt.figure(figsize=(50,10))

tree.plot_tree(
    model,
    feature_names=X.columns,
    class_names=model.classes_,
    filled=True,
    rounded=True
)

plt.title("tree classification")
plt.show()

# %%
#We create a new visualization

new_customer = [[34, 5100, 5]]

prediction= model.predict(new_customer)

print("new prediction")


print("Result:", prediction[0])
# Out:
# new prediction
# Result: Si
# c:\Users\Selene\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
